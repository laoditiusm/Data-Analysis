# %% [markdown]
# DATA CLEANING with AlexTheAnalyst
# ----
#
# Clean Customer Details
#
# Actions
# - Exploratory Analysis
# - Drop duplicates
# - Clean columns
# - Standardize Columns
# - Drop Columns

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("Customer Call List.xlsx")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# Display DataFrame

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 17        1018      Clark         Kent    7066950392
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
# 20            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6               False
# 7               False
# 8               False
# 9                True
# 10               True
# 11               True
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17               True
# 18               True
# 19               True
# 20               True

# %% [markdown]
# DROP Duplicates

# %%
df = df.drop_duplicates()

# %%
pd.options.mode.copy_on_write = True

# %%
df['Last_Name'] = df['Last_Name'].str.replace(r'[\.\/_]' ,'', regex=True,)
df['Last_Name'] = df['Last_Name'].fillna('')

# %%
df['Phone_Number'] = df['Phone_Number'].replace(to_replace=r'[^a-zA-Z0-9]|Na', value='', regex=True)
df['Phone_Number'] = df['Phone_Number'].fillna('')

# %%
df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6
# 7     8766783469
# 8
# 9     1235455421
# 10
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %% [markdown]
# CONVERT Column data type to string

# %%
df['Phone_Number'] = df['Phone_Number'].astype(str)

# %% [markdown]
# VIEW data frame

# %%
df
# Out:
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White   7066950392
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf
# 9         1010      Peter      Parker   1235455421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter   7066950392
# 12        1013        Don      Draper   1235432345
# 13        1014     Leslie       Knope   8766783469
# 14        1015       Toby  Flenderson   3047622467
# 15        1016        Ron     Weasley   1235455421
# 16        1017   Michael        Scott   1236439775
# 17        1018      Clark        Kent   7066950392
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker   8766783469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 0                True
# 1               False
# 2                True
# 3                True
# 4                True
# 5                True
# 6               False
# 7               False
# 8               False
# 9                True
# 10               True
# 11               True
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17               True
# 18               True
# 19               True

# %% [markdown]
# STANDARDIZE phone number column 000-000-0000

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[:3] + '-' + x[3:6] + '-' + x[6:10] if len(x) else '')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway               N            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road               Y             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive               N             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue               Y            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue               N             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane               Y            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column Valid-Numnber
# 0                True  123-545-5421
# 1               False  123-643-9775
# 2                True  706-695-0392
# 3                True  123-543-2345
# 4                True  876-678-3469
# 5                True  304-762-2467
# 6               False
# 7               False  876-678-3469
# 8               False
# 9                True  123-545-5421
# 10               True
# 11               True  706-695-0392
# 12              False  123-543-2345
# 13              False  876-678-3469
# 14              False  304-762-2467
# 15              False  123-545-5421
# 16              False  123-643-9775
# 17               True  706-695-0392
# 18               True
# 19               True  876-678-3469

# %% [markdown]
# STANDARDIZE column - Y -> Yes, N -> No

# %%
df['Paying Customer'] = df['Paying Customer'].apply(lambda x: 'Yes' if x.lower() == 'y' else 'No' if x.lower() == 'n' else x)

# %% [markdown]
# VIEW dataframe

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway              No            NaN
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                        123 Dragons Road             Yes             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive              No             No
# 8                        123 Middle Earth             Yes            NaN
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue             Yes            NaN
# 12                       2039 Main Street             Yes              N
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue              No             No
# 15                   2395 Hogwarts Avenue              No              N
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane             Yes            NaN
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column   Lo
# 0                True   No
# 1               False   No
# 2                True   No
# 3                True   No
# 4                True  Yes
# 5                True   No
# 6               False   No
# 7               False   No
# 8               False   No
# 9                True   No
# 10               True   No
# 11               True  Yes
# 12              False   No
# 13              False   No
# 14              False   No
# 15              False   No
# 16              False   No
# 17               True  Yes
# 18               True   No
# 19               True   No

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].astype(str)

# %% [markdown]
# STANDARDIZE the Do_Not_Contact column

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].apply(lambda x: 'No' if x.lower() == 'n' else 'Yes' if x.lower() == 'y' else x)

# %% [markdown]
# VIEW Dataframe

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway              No            nan
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes            Yes
# 4                        123 Dragons Road             Yes             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive              No             No
# 8                        123 Middle Earth             Yes            nan
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue             Yes            nan
# 12                       2039 Main Street             Yes             No
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue              No             No
# 15                   2395 Hogwarts Avenue              No             No
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane             Yes            nan
# 18                                    N/a             N/a            Yes
# 19            910 Tatooine Road, Tatooine             Yes             No
#
#     Not_Useful_Column   Lo
# 0                True   No
# 1               False   No
# 2                True   No
# 3                True   No
# 4                True  Yes
# 5                True   No
# 6               False   No
# 7               False   No
# 8               False   No
# 9                True   No
# 10               True   No
# 11               True  Yes
# 12              False   No
# 13              False   No
# 14              False   No
# 15              False   No
# 16              False   No
# 17               True  Yes
# 18               True   No
# 19               True   No

# %% [markdown]
# CLEAN UP the dataframe

# %%
df = df.replace(to_replace=r'N/a|nan', value='', regex=True)

# %% [markdown]
# VIEW dataframe

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 18        1019      Creed      Braton
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# 1                     93 West Main Street              No            Yes
# 2                      298 Drugs Driveway              No
# 3   980 Paper Avenue, Pennsylvania, 18503             Yes            Yes
# 4                        123 Dragons Road             Yes             No
# 5                        768 City Parkway             Yes            Yes
# 6                       1209 South Street              No             No
# 7                           98 Clue Drive              No             No
# 8                        123 Middle Earth             Yes
# 9              25th Main Street, New York             Yes             No
# 10                  612 Shire Lane, Shire             Yes             No
# 11                   2394 Hogwarts Avenue             Yes
# 12                       2039 Main Street             Yes             No
# 13                       343 City Parkway             Yes             No
# 14                          214 HR Avenue              No             No
# 15                   2395 Hogwarts Avenue              No             No
# 16         121 Paper Avenue, Pennsylvania             Yes             No
# 17                        3498 Super Lane             Yes
# 18                                                                   Yes
# 19            910 Tatooine Road, Tatooine             Yes             No
#
#     Not_Useful_Column   Lo
# 0                True   No
# 1               False   No
# 2                True   No
# 3                True   No
# 4                True  Yes
# 5                True   No
# 6               False   No
# 7               False   No
# 8               False   No
# 9                True   No
# 10               True   No
# 11               True  Yes
# 12              False   No
# 13              False   No
# 14              False   No
# 15              False   No
# 16              False   No
# 17               True  Yes
# 18               True   No
# 19               True   No

# %% [markdown]
# RETRIEVE ONLY the required data

# %%
finalDF = df[(df['Do_Not_Contact'] == 'No') & (df['Phone_Number'] != '')]

# %%
finalDF.reset_index(inplace=True)

# %% [markdown]
# VIEW Cleaned Table

# %%
finalDF
# Out:
#    level_0  index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0        0      0        1001      Frodo     Baggins  123-545-5421
# 1        4      4        1005        Jon        Snow  876-678-3469
# 2        7      7        1008   Sherlock      Holmes  876-678-3469
# 3        9      9        1010      Peter      Parker  123-545-5421
# 4       12     12        1013        Don      Draper  123-543-2345
# 5       13     13        1014     Leslie       Knope  876-678-3469
# 6       14     14        1015       Toby  Flenderson  304-762-2467
# 7       15     15        1016        Ron     Weasley  123-545-5421
# 8       16     16        1017   Michael        Scott  123-643-9775
# 9       19     19        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact
# 0           123 Shire Lane, Shire             Yes             No
# 1                123 Dragons Road             Yes             No
# 2                   98 Clue Drive              No             No
# 3      25th Main Street, New York             Yes             No
# 4                2039 Main Street             Yes             No
# 5                343 City Parkway             Yes             No
# 6                   214 HR Avenue              No             No
# 7            2395 Hogwarts Avenue              No             No
# 8  121 Paper Avenue, Pennsylvania             Yes             No
# 9     910 Tatooine Road, Tatooine             Yes             No
